# %%
import numpy as np
rng=np.random.default_rng(1303)
from matplotlib.pyplot import subplots
import pandas as pd

import  matplotlib.pyplot as plt

# %%
Auto=pd.read_csv("Auto.csv",na_values=["?"])
Auto.drop(index=range(9,85))
hola
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
#I removed the column "name" (because it was qualitative). 
#Then I computed the mean and standard deviation of each column and I created the data frame

Auto2=Auto.drop(columns="name")
column_mean= Auto2.mean()
column_min= Auto2.min()

results_Auto=pd.concat([column_mean, column_min],axis=1)
results_Auto.columns = ['Mean', 'Standard Deviation']
results_Auto
# Out:
#                      Mean  Standard Deviation
# mpg             23.515869                 9.0
# cylinders        5.458438                 3.0
# displacement   193.532746                68.0
# horsepower     104.469388                46.0
# weight        2970.261965              1613.0
# acceleration    15.555668                 8.0
# year            75.994962                70.0
# origin           1.574307                 1.0

# %%
#I would like to create a data frame where the rows are the mean, min, max and std of each column of auto. 
#first of all I create the vector of mean, min, max and std 
list_of_columns_without_the_column_name=Auto.drop(columns="name").columns
list_of_columns_without_the_column_name


Auto_mean=Auto[list_of_columns_without_the_column_name].mean()
Auto_min=Auto[list_of_columns_without_the_column_name].min()
Auto_max=Auto[list_of_columns_without_the_column_name].max()
Auto_std=Auto[list_of_columns_without_the_column_name].std()

Auto_mean2=Auto_mean.tolist()
Auto_min2=Auto_min.tolist()
Auto_max2=Auto_max.tolist()
Auto_std2=Auto_std.tolist()

print(Auto_min2)
print()
print(Auto_min)
# Out:
# [9.0, 3.0, 68.0, 46.0, 1613.0, 8.0, 70.0, 1.0]
#
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# origin             1.0
# dtype: float64

# %%
data = [Auto_min2, Auto_max2, Auto_mean2, Auto_std2]
columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']
index = ["min", "max", "mean", "std"]

Auto_df = pd.DataFrame(data, columns=columns, index=index)
Auto_df
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min    9.000000   3.000000     68.000000   46.000000  1613.000000
# max   46.600000   8.000000    455.000000  230.000000  5140.000000
# mean  23.515869   5.458438    193.532746  104.469388  2970.261965
# std    7.825804   1.701577    104.379583   38.491160   847.904119
#
#       acceleration       year    origin
# min       8.000000  70.000000  1.000000
# max      24.800000  82.000000  3.000000
# mean     15.555668  75.994962  1.574307
# std       2.749995   3.690005  0.802549

# %%
#scatter plot
fig, axes = plt.subplots(figsize=(10, 10))

# Use pd.plotting.scatter_matrix
pd.plotting.scatter_matrix(Auto, ax=axes)

# Show the plot
plt.show()
# Out:
# C:\Users\cex\AppData\Local\Temp\ipykernel_6948\1472551454.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   pd.plotting.scatter_matrix(Auto, ax=axes)

# %%
pd.plotting.scatter_matrix(Auto[['mpg',
                                 'displacement',
                                 'weight']]);

# %%
#item d
#remove the 10th through the 85th observation
Auto.drop(index=range(9,85))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
#item f 
mpg_column = Auto['mpg']

# Specify the dimensions of the figure
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Create individual scatter plots for 'mpg' versus other columns
for i, column in enumerate(Auto.columns[1:]):
    axes[i].scatter(Auto[column], mpg_column)
    axes[i].set_title(f'Scatter plot of mpg vs {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('mpg')

# Adjust layout for better visibility
fig.tight_layout()

# Show the plot
plt.show()

# %%
for column in Auto.columns[1:]:
    plt.scatter(Auto[column], mpg_column)
    plt.title(f'Scatter plot of mpg vs {column}')
    plt.xlabel(column)
    plt.ylabel('mpg')
    plt.show()

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
fig, ax = subplots(figsize=(5, 5))
Auto.boxplot('displacement', by='year', ax=ax);
