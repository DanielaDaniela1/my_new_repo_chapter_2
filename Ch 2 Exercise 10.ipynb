# %%
import numpy as np
rng=np.random.default_rng(1303)
from matplotlib.pyplot import subplots
import pandas as pd
import  matplotlib.pyplot as plt

# %%
#item a
#import the data with a "path". The data is not in the same folder than this file, therefore I need to "call them" by:
path = r"C:\Users\cex\Desktop\DaniVir\ALL CSV FILES - 2nd Edition\Boston.csv"
Boston = pd.read_csv(path)
Boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %%
#item b
#number of rows and columns
Boston.shape
# Out:
# (506, 14)

# %%
#item c
#scatter plot, "all vs all"
fig, axes = plt.subplots(figsize=(20, 20))

# Use pd.plotting.scatter_matrix
pd.plotting.scatter_matrix(Boston, ax=axes)

# Show the plot
plt.show()
# Out:
# C:\Users\cex\AppData\Local\Temp\ipykernel_328\1833736047.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   pd.plotting.scatter_matrix(Boston, ax=axes)

# %%
#item d
#scatter plot of crim vs each column. 
crim_column = Boston['crim']

# Specify the dimensions of the figure
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(12, 6))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Create individual scatter plots for 'mpg' versus other columns
for i, column in enumerate(Boston.columns[1:]):
    axes[i].scatter(Boston[column], crim_column)
    axes[i].set_title(f'Scatter plot of crim vs {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('crim')

# Adjust layout for better visibility
fig.tight_layout()

# Show the plot
plt.show()

# %%
#correletation matrix
crim_column = Boston['crim']
correlation_matrix = Boston.corrwith(crim_column)
correlation_matrix
# Out:
# crim       1.000000
# zn        -0.200469
# indus      0.406583
# chas      -0.055892
# nox        0.420972
# rm        -0.219247
# age        0.352734
# dis       -0.379670
# rad        0.625505
# tax        0.582764
# ptratio    0.289946
# black     -0.385064
# lstat      0.455621
# medv      -0.388305
# dtype: float64

# %%
v=np.array([7,8,9])
w=np.array([4,5,6])
a=[1,2,3]
z=[0,1,2]
for i in z:
    a[i]=(v[i]*w[i])
    
print(sum(a))
# Out:
# 122

# %%
Boston.shape
# Out:
# (506, 14)

# %%
# Out:
# 29.392647611199564
# 24.943949171284356

# %%
#scatter plot of medv vs crim
ax.scatter( Boston['medv'],Boston['crim'])
fig.set_size_inches(3,3)
ax.set_xlabel("medv")
ax.set_ylabel("crim")
ax.set_title("Plot of crim vs medv");
fig
#another way to do this is directly plt.scatter( Boston['medv'],Boston['crim']), 
#but to change the size is not so obvious.

# %%
#another way to create the scatter plot of medv vs crim

fig, ax = subplots(figsize=(3, 3))
ax.scatter( Boston['medv'],Boston['crim'], marker='o');
ax.set_xlabel("medv")
ax.set_ylabel("crim")
ax.set_title("Plot of crim vs medv");

# %%
#I sorted the data frame by crim rate (descending)
Boston.sort_values(
    by="tax",
   ascending=False)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age      dis  rad  \
# 492         493  0.11132   0.0  27.74     0  0.609  5.983  83.5   2.1099    4
# 491         492  0.10574   0.0  27.74     0  0.609  5.983  98.8   1.8681    4
# 490         491  0.20746   0.0  27.74     0  0.609  5.093  98.0   1.8226    4
# 489         490  0.18337   0.0  27.74     0  0.609  5.414  98.3   1.7554    4
# 488         489  0.15086   0.0  27.74     0  0.609  5.454  92.7   1.8209    4
# ..          ...      ...   ...    ...   ...    ...    ...   ...      ...  ...
# 121         122  0.07165   0.0  25.65     0  0.581  6.004  84.1   2.1974    2
# 120         121  0.06899   0.0  25.65     0  0.581  5.870  69.7   2.2577    2
# 125         126  0.16902   0.0  25.65     0  0.581  5.986  88.4   1.9929    2
# 124         125  0.09849   0.0  25.65     0  0.581  5.879  95.8   2.0063    2
# 353         354  0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5
#
#      tax  ptratio  lstat  medv
# ...

# %%
fig, ax = subplots(figsize=(4, 4))
x = Boston["crim"]
ax.plot(x);

# %%
#grafico para ayudar a enter cuánto sería tasa alta de crimen 
Boston2=Boston.sort_values(
    by="crim",
   ascending=True)
sorted_Boston.sort_index()

Boston3=Boston2.reset_index()
fig, ax = subplots(figsize=(4, 4))
x = Boston3["crim"]
ax.plot(x);
# Out:
# 29.392647611199564

# %%
#compute the mean plus three squared devition of crim and ptratio

v=Boston["crim"],Boston["ptratio"]
for i in v:
    print(np.mean(i)+3*np.std(i))
# Out:
# 29.392647611199564
# 24.943949171284356

# %%
#number of suburbs that bound the Charles river
sum(Boston["chas"])
# Out:
# 35

# %%
#media of the pupil-teacher ratio
np.median(Boston["ptratio"])
# Out:
# 19.05

# %%
#item h. 
#forma 1 "manual": I sorted the data frame by medv in ascending orden. Then I extract the corresponding row. 
Boston4=Boston.sort_values(
    by="medv",
   ascending=True)
Boston4
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 398         399  38.35180   0.0  18.10     0  0.693  5.453  100.0  1.4896
# 405         406  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254
# 400         401  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888
# 399         400   9.91655   0.0  18.10     0  0.693  5.852   77.8  1.5004
# 414         415  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 166         167   2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459
# 195         196   0.01381  80.0   0.46     0  0.422  7.875   32.0  5.6484
# 283         284   0.01501  90.0   1.21     1  0.401  7.923   24.8  5.8850
# 225         226   0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944
# 186         187   0.05602   0.0   2.46     0  0.488  7.831   53.6  3.1992
#
#      rad  tax  ptratio  lstat  medv
# 398   24  666     20.2  30.59   5.0
# ...

# %%
#item h. 
#forma 2
np.min(Boston["medv"])
idx = Boston["medv"]==np.min(Boston["medv"])
Boston[idx]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio   black  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %%
Boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
#item i
sum(Boston["rm"]>7),sum(Boston["rm"]>8)
# Out:
# (64, 13)

# %%
idx2=Boston["rm"]>8
Boston[idx2].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...
